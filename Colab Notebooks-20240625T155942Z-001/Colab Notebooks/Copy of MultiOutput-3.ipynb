# %% [markdown]
# # Ejemplo de un problema de clasificación con múltiples salidas
#
# Una de las formas de solucionar la actividad de esta unidad (Captchas) requiere configurar un modelo de clasificación con 5 salidas. Una por cada símbolo en la imagen. Para este ejemplo, usaremos un conjunto de datos de imágenes, a partir de las cuales se debe predecir: la edad, el género y la Etnicidad.

# %% [markdown]
# ## Etapa 1: Carga de los datos

# %%
import numpy as np

# %matplotlib inline
from keras.utils import plot_model
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from keras impo frt layers
from keras.models import Model
from keras.models import load_model
import pandas as pd
import cv2
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Se carga la base de datos, el archivo csv puede ser descargado desde: https://www.kaggle.com/datasets/nipunarora8/age-gender-and-ethnicity-face-data-csv?resource=download
#
# La base de datos tiene 4 columnas: Age, Ethnicity y Gender corresponden a las salidas que se deben predecir. Por otro lado, pixels contiene la información de las imágenes.

# %%
# !pip install jovian --upgrade --quiet
# !pip install opendatasets --upgrade --quiet
import opendatasets as od
od.download('https://www.kaggle.com/datasets/nipunarora8/age-gender-and-ethnicity-face-data-csv?resource=download')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 727.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for uuid (setup.py) ... done
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: julingilgonzlez
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/nipunarora8/age-gender-and-ethnicity-face-data-csv
# Downloading age-gender-and-ethnicity-face-data-csv.zip to ./age-gender-and-ethnicity-face-data-csv
# 100%|██████████| 63.2M/63.2M [00:00<00:00, 147MB/s]

# %%
D = pd.read_csv('/content/age-gender-and-ethnicity-face-data-csv/age_gender.csv')
D
# Out:
#        age  ethnicity  gender                        img_name  \
# 0        1          2       0  20161219203650636.jpg.chip.jpg
# 1        1          2       0  20161219222752047.jpg.chip.jpg
# 2        1          2       0  20161219222832191.jpg.chip.jpg
# 3        1          2       0  20161220144911423.jpg.chip.jpg
# 4        1          2       0  20161220144914327.jpg.chip.jpg
# ...    ...        ...     ...                             ...
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 0      129 128 128 126 127 130 133 135 139 142 145 14...
# 1      164 74 111 168 169 171 175 182 184 188 193 199...
# 2      67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3      193 197 198 200 199 200 202 203 204 205 208 21...
# 4      202 205 209 210 209 209 210 211 212 214 218 21...
# ...                                                  ...
# 23700  127 100 94 81 77 77 74 99 102 98 128 145 160 1...
# 23701  23 28 32 35 42 47 68 85 98 103 113 117 130 129...
# 23702  59 50 37 40 34 19 30 101 156 170 177 184 187 1...
# 23703  45 108 120 156 206 197 140 180 191 199 204 207...
# 23704  156 161 160 165 170 173 166 177 183 191 187 18...
#
# [23705 rows x 5 columns]

# %%
D.pixels
# Out:
# 0        129 128 128 126 127 130 133 135 139 142 145 14...
# 1        164 74 111 168 169 171 175 182 184 188 193 199...
# 2        67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3        193 197 198 200 199 200 202 203 204 205 208 21...
# 4        202 205 209 210 209 209 210 211 212 214 218 21...
#                                ...
# 23700    127 100 94 81 77 77 74 99 102 98 128 145 160 1...
# 23701    23 28 32 35 42 47 68 85 98 103 113 117 130 129...
# 23702    59 50 37 40 34 19 30 101 156 170 177 184 187 1...
# 23703    45 108 120 156 206 197 140 180 191 199 204 207...
# 23704    156 161 160 165 170 173 166 177 183 191 187 18...
# Name: pixels, Length: 23705, dtype: object

# %% [markdown]
# ## Etapa 2: Procesamiento de las imágens y las etiquetas

# %%
# Las imágenes no están representadas adeucadamente. Esta parte del código adecua
# las imágenes.
Images = D.pixels.apply(lambda x: np.array(x.split(" "),dtype=float))
X = np.stack(Images)
X = X / 255.0
X = X.astype('float32')
X = X.reshape(X.shape[0], 48, 48, 1)

# %%
# Ahora tenemos 23705 imágenes en escala de grises de tamaño 48x48x1
X.shape
# Out:
# (23705, 48, 48, 1)

# %%
# Se extraen las etiquetas
# 1. Age: la salida Age toma valores enteros, si se asume como clasificación se
# configurarían muchas clases (una por cada edad). Para disminuir la cantidad de
# clases, se plantea una umbralización, por ejemplo, las edades entre 0 y 9 se
# asignan a la clase 0, las edades entre 10 y 15 en la clase 1 y así sucesivamente.
# De esta forma la salida age tiene 9 clases.
age_bins = [0,10,15,20,25,30,40,50,60,120]
age_labels = [0, 1, 2, 3, 4, 5, 6, 7, 8]
D['age'] = pd.cut(D.age, bins=age_bins, labels=age_labels)
age =  np.expand_dims(np.array(D.age[:]), -1)
gender = np.expand_dims(np.array(D.gender[:]), -1)
eth = np.expand_dims(np.array(D.ethnicity[:]), -1)

print(len(np.unique(age))) #clases
print(len(np.unique(gender)))
print(len(np.unique(eth)))

# tener en cuenta este orden: primero age, que tiene 9 clases, segundo gender con
# dos clases y tercero eth con 5 clases.
Y = np.concatenate((age, gender, eth), axis=1)
# Out:
# 9
# 2
# 5

# %%
# Se definen los conjuntos de entrenamiento y prueba.
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
h = X_train.shape[1]
w  = X_train.shape[2]
c = X_train.shape[3]
input_shape = (h, w, c)
print(input_shape) #tamaño de las imágenes
# Out:
# (48, 48, 1)

# %% [markdown]
# ## 3. Definición del modelo

# %%
def createmodel():
    # se define una serie de capas convolucionales. Esta parte es igual al resto
    # de redes que se han usado
    img = layers.Input(shape=(input_shape))
    conv1 = layers.Conv2D(16, (3, 3), padding='same', activation='relu')(img)
    mp1 = layers.MaxPooling2D(padding='same')(conv1)
    conv2 = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(mp1)
    mp2 = layers.MaxPooling2D(padding='same')(conv2)
    conv3 = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(mp2)
    bn = layers.BatchNormalization()(conv3)
    mp3 = layers.MaxPooling2D(padding='same')(bn)

    flat = layers.Flatten()(mp3)

    # A partir de esta línea es donde empiezan los cambios. Tenemos 3 salidas.
    # La primera configura un problema con 9 clases, la segunda es una clasificación
    # binaria y la tercer una clasificación con 5 clases
    outs = [] # En esta lista se guardan las tres salidas. Las tres salidas se
    # aimentan de la salida de la capa flat.

    # Cada salida puede configurarse con diferents tipos de capas, a modo de ejemplo,
    # acá se utilizan estrucutras idénticas.

    # Salida 1: Clasificación con 9 clases.
    den_1 = layers.Dense(64, activation='relu')(flat)
    drop_1 = layers.Dropout(0.5)(den_1)
    sal_1 = layers.Dense(9, activation='Softmax')(drop_1)
    outs.append(sal_1) #se añade el resultado a la lista

    # Salida 2: Clasificación binaria.
    den_2 = layers.Dense(64, activation='relu')(flat)
    drop_2 = layers.Dropout(0.5)(den_2)
    sal_2 = layers.Dense(1, activation='sigmoid')(drop_2)
    outs.append(sal_2) #se añade el resultado a la lista

    # Salida 3: Clasificación con 5 clases.
    den_3 = layers.Dense(64, activation='relu')(flat)
    drop_3 = layers.Dropout(0.5)(den_3)
    sal_3 = layers.Dense(5, activation='Softmax')(drop_3)
    outs.append(sal_3) #se añade el resultado a la lista

    # Compile model and return it
    model = Model(img, outs) #create model
    # Se crea una lista de funciones Loss, una por cada salida. La primera y la
    # tercera son salidas de clasificación de múltiples clases, por lo tanto se
    # usa sparse_categorical_crossentropy, para la segunda función se usa la
    # binary_crossentropy
    Loss = ['sparse_categorical_crossentropy','binary_crossentropy','sparse_categorical_crossentropy']
    model.compile(loss=Loss, optimizer='adam',metrics=["accuracy"])
    return model

# %%
model = createmodel()
tf.keras.utils.plot_model(model)

# %%
hist = model.fit(X_train, [ y_train[:,0], # salida age
                           y_train[:,1], # salida gender
                           y_train[:,2] ]  # salida eth]
                           , batch_size=32, epochs=30,
                           validation_data=(X_test, [y_test[:,0],
                                                     y_test[:,1],
                                                     y_test[:,2]]))
# Out:
# Epoch 1/30
# 519/519 [==============================] - 18s 12ms/step - loss: 3.5060 - dense_1_loss: 1.8547 - dense_3_loss: 0.4769 - dense_5_loss: 1.1743 - dense_1_accuracy: 0.3045 - dense_3_accuracy: 0.7616 - dense_5_accuracy: 0.5566 - val_loss: 3.2965 - val_dense_1_loss: 1.7755 - val_dense_3_loss: 0.4279 - val_dense_5_loss: 1.0932 - val_dense_1_accuracy: 0.3585 - val_dense_3_accuracy: 0.8272 - val_dense_5_accuracy: 0.6384
# Epoch 2/30
# 519/519 [==============================] - 5s 9ms/step - loss: 2.8865 - dense_1_loss: 1.6015 - dense_3_loss: 0.3443 - dense_5_loss: 0.9407 - dense_1_accuracy: 0.3879 - dense_3_accuracy: 0.8438 - dense_5_accuracy: 0.6646 - val_loss: 2.6831 - val_dense_1_loss: 1.5783 - val_dense_3_loss: 0.3167 - val_dense_5_loss: 0.7881 - val_dense_1_accuracy: 0.3841 - val_dense_3_accuracy: 0.8595 - val_dense_5_accuracy: 0.7205
# Epoch 3/30
# 519/519 [==============================] - 5s 9ms/step - loss: 2.6512 - dense_1_loss: 1.5059 - dense_3_loss: 0.3067 - dense_5_loss: 0.8386 - dense_1_accuracy: 0.4115 - dense_3_accuracy: 0.8625 - dense_5_accuracy: 0.7037 - val_loss: 2.5422 - val_dense_1_loss: 1.4834 - val_dense_3_loss: 0.2992 - val_dense_5_loss: 0.7596 - val_dense_1_accuracy: 0.4269 - val_dense_3_accuracy: 0.8667 - val_dense_5_accuracy: 0.7268
# Epoch 4/30
# 519/519 [==============================] - 6s 11ms/step - loss: 2.5336 - dense_1_loss: 1.4519 - dense_3_loss: 0.2899 - dense_5_loss: 0.7918 - dense_1_accuracy: 0.4321 - dense_3_accuracy: 0.8707 - dense_5_accuracy: 0.7227 - val_loss: 2.4217 - val_dense_1_loss: 1.4195 - val_dense_3_loss: 0.2867 - val_dense_5_loss: 0.7156 - val_dense_1_accuracy: 0.4379 - val_dense_3_accuracy: 0.8753 - val_dense_5_accuracy: 0.7487
# Epoch 5/30
# 519/519 [==============================] - 5s 9ms/step - loss: 2.4251 - dense_1_loss: 1.4111 - dense_3_loss: 0.2718 - dense_5_loss: 0.7422 - dense_1_accuracy: 0.4424 - dense_3_accuracy: 0.8795 - dense_5_accuracy: 0.7400 - val_loss: 2.4284 - val_dense_1_loss: 1.4355 - val_dense_3_loss: 0.2890 - val_dense_5_loss: 0.7039 - val_dense_1_accuracy: 0.4422 - val_dense_3_accuracy: 0.8753 - val_dense_5_accuracy: 0.7514
# Epoch 6/30
# 519/519 [==============================] - 5s 9ms/step - loss: 2.3625 - dense_1_loss: 1.3841 - dense_3_loss: 0.2587 - dense_5_loss: 0.7197 - dense_1_accuracy: 0.4471 - dense_3_accuracy: 0.8860 - dense_5_accuracy: 0.7479 - val_loss: 3.0063 - val_dense_1_loss: 1.8477 - val_dense_3_loss: 0.2905 - val_dense_5_loss: 0.8682 - val_dense_1_accuracy: 0.3532 - val_dense_3_accuracy: 0.8680 - val_dense_5_accuracy: 0.7123
# Epoch 7/30
# 519/519 [==============================] - 6s 11ms/step - loss: 2.2959 - dense_1_loss: 1.3549 - dense_3_loss: 0.2477 - dense_5_loss: 0.6932 - dense_1_accuracy: 0.4580 - dense_3_accuracy: 0.8910 - dense_5_accuracy: 0.7572 - val_loss: 2.4224 - val_dense_1_loss: 1.4236 - val_dense_3_loss: 0.2864 - val_dense_5_loss: 0.7123 - val_dense_1_accuracy: 0.4293 - val_dense_3_accuracy: 0.8792 - val_dense_5_accuracy: 0.7507
# Epoch 8/30
# 519/519 [==============================] - 5s 10ms/step - loss: 2.2446 - dense_1_loss: 1.3286 - dense_3_loss: 0.2433 - dense_5_loss: 0.6727 - dense_1_accuracy: 0.4622 - dense_3_accuracy: 0.8962 - dense_5_accuracy: 0.7668 - val_loss: 2.2990 - val_dense_1_loss: 1.3443 - val_dense_3_loss: 0.2690 - val_dense_5_loss: 0.6857 - val_dense_1_accuracy: 0.4634 - val_dense_3_accuracy: 0.8878 - val_dense_5_accuracy: 0.7605
# Epoch 9/30
# 519/519 [==============================] - 5s 9ms/step - loss: 2.1825 - dense_1_loss: 1.3016 - dense_3_loss: 0.2315 - dense_5_loss: 0.6494 - dense_1_accuracy: 0.4757 - dense_3_accuracy: 0.9019 - dense_5_accuracy: 0.7698 - val_loss: 2.3908 - val_dense_1_loss: 1.4400 - val_dense_3_loss: 0.2644 - val_dense_5_loss: 0.6864 - val_dense_1_accuracy: 0.4429 - val_dense_3_accuracy: 0.8858 - val_dense_5_accuracy: 0.7582
# Epoch 10/30
# 519/519 [==============================] - 6s 12ms/step - loss: 2.1316 - dense_1_loss: 1.2874 - dense_3_loss: 0.2177 - dense_5_loss: 0.6264 - dense_1_accuracy: 0.4783 - dense_3_accuracy: 0.9073 - dense_5_accuracy: 0.7799 - val_loss: 2.5789 - val_dense_1_loss: 1.5702 - val_dense_3_loss: 0.2664 - val_dense_5_loss: 0.7424 - val_dense_1_accuracy: 0.4193 - val_dense_3_accuracy: 0.8893 - val_dense_5_accuracy: 0.7560
# Epoch 11/30
# 519/519 [==============================] - 4s 9ms/step - loss: 2.0958 - dense_1_loss: 1.2691 - dense_3_loss: 0.2092 - dense_5_loss: 0.6176 - dense_1_accuracy: 0.4819 - dense_3_accuracy: 0.9129 - dense_5_accuracy: 0.7801 - val_loss: 3.3510 - val_dense_1_loss: 2.2305 - val_dense_3_loss: 0.2892 - val_dense_5_loss: 0.8313 - val_dense_1_accuracy: 0.3261 - val_dense_3_accuracy: 0.8888 - val_dense_5_accuracy: 0.7066
# Epoch 12/30
# 519/519 [==============================] - 5s 10ms/step - loss: 2.0497 - dense_1_loss: 1.2478 - dense_3_loss: 0.2035 - dense_5_loss: 0.5983 - dense_1_accuracy: 0.4887 - dense_3_accuracy: 0.9137 - dense_5_accuracy: 0.7909 - val_loss: 2.5710 - val_dense_1_loss: 1.5101 - val_dense_3_loss: 0.2934 - val_dense_5_loss: 0.7676 - val_dense_1_accuracy: 0.4238 - val_dense_3_accuracy: 0.8848 - val_dense_5_accuracy: 0.7503
# Epoch 13/30
# 519/519 [==============================] - 6s 11ms/step - loss: 2.0015 - dense_1_loss: 1.2274 - dense_3_loss: 0.1906 - dense_5_loss: 0.5835 - dense_1_accuracy: 0.4938 - dense_3_accuracy: 0.9201 - dense_5_accuracy: 0.7930 - val_loss: 2.3107 - val_dense_1_loss: 1.3566 - val_dense_3_loss: 0.2757 - val_dense_5_loss: 0.6784 - val_dense_1_accuracy: 0.4640 - val_dense_3_accuracy: 0.8843 - val_dense_5_accuracy: 0.7659
# Epoch 14/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.9680 - dense_1_loss: 1.2127 - dense_3_loss: 0.1861 - dense_5_loss: 0.5691 - dense_1_accuracy: 0.4954 - dense_3_accuracy: 0.9209 - dense_5_accuracy: 0.7933 - val_loss: 2.5375 - val_dense_1_loss: 1.5533 - val_dense_3_loss: 0.2800 - val_dense_5_loss: 0.7042 - val_dense_1_accuracy: 0.4266 - val_dense_3_accuracy: 0.8896 - val_dense_5_accuracy: 0.7659
# Epoch 15/30
# 519/519 [==============================] - 6s 12ms/step - loss: 1.9197 - dense_1_loss: 1.1883 - dense_3_loss: 0.1780 - dense_5_loss: 0.5533 - dense_1_accuracy: 0.5095 - dense_3_accuracy: 0.9234 - dense_5_accuracy: 0.8039 - val_loss: 2.3921 - val_dense_1_loss: 1.3946 - val_dense_3_loss: 0.2914 - val_dense_5_loss: 0.7061 - val_dense_1_accuracy: 0.4625 - val_dense_3_accuracy: 0.8867 - val_dense_5_accuracy: 0.7645
# Epoch 16/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.8947 - dense_1_loss: 1.1837 - dense_3_loss: 0.1720 - dense_5_loss: 0.5390 - dense_1_accuracy: 0.5067 - dense_3_accuracy: 0.9250 - dense_5_accuracy: 0.8055 - val_loss: 2.4450 - val_dense_1_loss: 1.4135 - val_dense_3_loss: 0.3020 - val_dense_5_loss: 0.7295 - val_dense_1_accuracy: 0.4573 - val_dense_3_accuracy: 0.8843 - val_dense_5_accuracy: 0.7627
# Epoch 17/30
# 519/519 [==============================] - 5s 9ms/step - loss: 1.8547 - dense_1_loss: 1.1576 - dense_3_loss: 0.1655 - dense_5_loss: 0.5317 - dense_1_accuracy: 0.5197 - dense_3_accuracy: 0.9294 - dense_5_accuracy: 0.8078 - val_loss: 2.3891 - val_dense_1_loss: 1.3742 - val_dense_3_loss: 0.3018 - val_dense_5_loss: 0.7131 - val_dense_1_accuracy: 0.4509 - val_dense_3_accuracy: 0.8816 - val_dense_5_accuracy: 0.7500
# Epoch 18/30
# 519/519 [==============================] - 8s 15ms/step - loss: 1.8274 - dense_1_loss: 1.1564 - dense_3_loss: 0.1605 - dense_5_loss: 0.5106 - dense_1_accuracy: 0.5219 - dense_3_accuracy: 0.9330 - dense_5_accuracy: 0.8151 - val_loss: 2.4597 - val_dense_1_loss: 1.4026 - val_dense_3_loss: 0.3092 - val_dense_5_loss: 0.7479 - val_dense_1_accuracy: 0.4513 - val_dense_3_accuracy: 0.8813 - val_dense_5_accuracy: 0.7610
# Epoch 19/30
# 519/519 [==============================] - 5s 9ms/step - loss: 1.7994 - dense_1_loss: 1.1424 - dense_3_loss: 0.1530 - dense_5_loss: 0.5040 - dense_1_accuracy: 0.5182 - dense_3_accuracy: 0.9349 - dense_5_accuracy: 0.8178 - val_loss: 2.4587 - val_dense_1_loss: 1.3573 - val_dense_3_loss: 0.3471 - val_dense_5_loss: 0.7543 - val_dense_1_accuracy: 0.4761 - val_dense_3_accuracy: 0.8867 - val_dense_5_accuracy: 0.7641
# Epoch 20/30
# 519/519 [==============================] - 6s 12ms/step - loss: 1.7494 - dense_1_loss: 1.1279 - dense_3_loss: 0.1438 - dense_5_loss: 0.4778 - dense_1_accuracy: 0.5270 - dense_3_accuracy: 0.9396 - dense_5_accuracy: 0.8256 - val_loss: 2.5047 - val_dense_1_loss: 1.3789 - val_dense_3_loss: 0.3367 - val_dense_5_loss: 0.7891 - val_dense_1_accuracy: 0.4681 - val_dense_3_accuracy: 0.8789 - val_dense_5_accuracy: 0.7593
# Epoch 21/30
# 519/519 [==============================] - 4s 9ms/step - loss: 1.7356 - dense_1_loss: 1.1078 - dense_3_loss: 0.1422 - dense_5_loss: 0.4856 - dense_1_accuracy: 0.5309 - dense_3_accuracy: 0.9398 - dense_5_accuracy: 0.8244 - val_loss: 2.5221 - val_dense_1_loss: 1.4060 - val_dense_3_loss: 0.3524 - val_dense_5_loss: 0.7638 - val_dense_1_accuracy: 0.4651 - val_dense_3_accuracy: 0.8872 - val_dense_5_accuracy: 0.7657
# Epoch 22/30
# 519/519 [==============================] - 4s 8ms/step - loss: 1.7087 - dense_1_loss: 1.1015 - dense_3_loss: 0.1401 - dense_5_loss: 0.4671 - dense_1_accuracy: 0.5353 - dense_3_accuracy: 0.9409 - dense_5_accuracy: 0.8293 - val_loss: 2.6853 - val_dense_1_loss: 1.4862 - val_dense_3_loss: 0.3719 - val_dense_5_loss: 0.8272 - val_dense_1_accuracy: 0.4546 - val_dense_3_accuracy: 0.8840 - val_dense_5_accuracy: 0.7524
# Epoch 23/30
# 519/519 [==============================] - 6s 11ms/step - loss: 1.6692 - dense_1_loss: 1.0861 - dense_3_loss: 0.1264 - dense_5_loss: 0.4567 - dense_1_accuracy: 0.5429 - dense_3_accuracy: 0.9467 - dense_5_accuracy: 0.8335 - val_loss: 2.5876 - val_dense_1_loss: 1.4981 - val_dense_3_loss: 0.3376 - val_dense_5_loss: 0.7519 - val_dense_1_accuracy: 0.4484 - val_dense_3_accuracy: 0.8874 - val_dense_5_accuracy: 0.7624
# Epoch 24/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.6632 - dense_1_loss: 1.0749 - dense_3_loss: 0.1278 - dense_5_loss: 0.4605 - dense_1_accuracy: 0.5454 - dense_3_accuracy: 0.9438 - dense_5_accuracy: 0.8326 - val_loss: 2.6073 - val_dense_1_loss: 1.5008 - val_dense_3_loss: 0.3233 - val_dense_5_loss: 0.7832 - val_dense_1_accuracy: 0.4370 - val_dense_3_accuracy: 0.8829 - val_dense_5_accuracy: 0.7559
# Epoch 25/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.6232 - dense_1_loss: 1.0595 - dense_3_loss: 0.1243 - dense_5_loss: 0.4394 - dense_1_accuracy: 0.5548 - dense_3_accuracy: 0.9462 - dense_5_accuracy: 0.8388 - val_loss: 2.8613 - val_dense_1_loss: 1.7306 - val_dense_3_loss: 0.3497 - val_dense_5_loss: 0.7810 - val_dense_1_accuracy: 0.4168 - val_dense_3_accuracy: 0.8858 - val_dense_5_accuracy: 0.7562
# Epoch 26/30
# 519/519 [==============================] - 6s 12ms/step - loss: 1.6098 - dense_1_loss: 1.0561 - dense_3_loss: 0.1184 - dense_5_loss: 0.4353 - dense_1_accuracy: 0.5554 - dense_3_accuracy: 0.9498 - dense_5_accuracy: 0.8370 - val_loss: 2.8902 - val_dense_1_loss: 1.7458 - val_dense_3_loss: 0.3679 - val_dense_5_loss: 0.7765 - val_dense_1_accuracy: 0.4149 - val_dense_3_accuracy: 0.8898 - val_dense_5_accuracy: 0.7576
# Epoch 27/30
# 519/519 [==============================] - 4s 8ms/step - loss: 1.5833 - dense_1_loss: 1.0457 - dense_3_loss: 0.1142 - dense_5_loss: 0.4233 - dense_1_accuracy: 0.5573 - dense_3_accuracy: 0.9525 - dense_5_accuracy: 0.8416 - val_loss: 2.5824 - val_dense_1_loss: 1.4445 - val_dense_3_loss: 0.3615 - val_dense_5_loss: 0.7764 - val_dense_1_accuracy: 0.4563 - val_dense_3_accuracy: 0.8851 - val_dense_5_accuracy: 0.7610
# Epoch 28/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.5795 - dense_1_loss: 1.0448 - dense_3_loss: 0.1148 - dense_5_loss: 0.4199 - dense_1_accuracy: 0.5571 - dense_3_accuracy: 0.9515 - dense_5_accuracy: 0.8417 - val_loss: 2.5594 - val_dense_1_loss: 1.4107 - val_dense_3_loss: 0.3617 - val_dense_5_loss: 0.7870 - val_dense_1_accuracy: 0.4703 - val_dense_3_accuracy: 0.8874 - val_dense_5_accuracy: 0.7583
# Epoch 29/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.5383 - dense_1_loss: 1.0190 - dense_3_loss: 0.1133 - dense_5_loss: 0.4060 - dense_1_accuracy: 0.5697 - dense_3_accuracy: 0.9515 - dense_5_accuracy: 0.8449 - val_loss: 2.7815 - val_dense_1_loss: 1.5576 - val_dense_3_loss: 0.3826 - val_dense_5_loss: 0.8414 - val_dense_1_accuracy: 0.4336 - val_dense_3_accuracy: 0.8888 - val_dense_5_accuracy: 0.7503
# Epoch 30/30
# 519/519 [==============================] - 5s 10ms/step - loss: 1.5159 - dense_1_loss: 1.0061 - dense_3_loss: 0.1069 - dense_5_loss: 0.4029 - dense_1_accuracy: 0.5710 - dense_3_accuracy: 0.9526 - dense_5_accuracy: 0.8508 - val_loss: 2.8377 - val_dense_1_loss: 1.6042 - val_dense_3_loss: 0.3864 - val_dense_5_loss: 0.8471 - val_dense_1_accuracy: 0.4350 - val_dense_3_accuracy: 0.8920 - val_dense_5_accuracy: 0.7485

# %%
preds = model.evaluate(X_test,[y_test[:,0], y_test[:,1],y_test[:,2]])
print('Acc_1:', preds[4])
print('Acc_2:', preds[5])
print('Acc_3:', preds[6])
# Out:
# 223/223 [==============================] - 1s 4ms/step - loss: 2.8377 - dense_1_loss: 1.6042 - dense_3_loss: 0.3864 - dense_5_loss: 0.8471 - dense_1_accuracy: 0.4350 - dense_3_accuracy: 0.8920 - dense_5_accuracy: 0.7485
# Acc_1: 0.43503937125205994
# Acc_2: 0.8920134902000427
# Acc_3: 0.7484533190727234
